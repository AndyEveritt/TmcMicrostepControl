# %%
from typing import Callable

import numpy as np
from scipy.fft import fft
import holoviews as hv
import panel as pn
from holoviews import opts

import plotting as plt
from LUT import LUT, CalculateFFT

hv.extension('bokeh')
opts.defaults(
    opts.Curve(height=400, responsive=True, tools=['hover'], show_grid=True),
    opts.Scatter(height=400, responsive=True, tools=['hover'], show_grid=True),
    opts.Bars(height=400, responsive=True, tools=['hover'], show_grid=True),
)
# Out:
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='df015450-5a24-4387-90dd-71debce953bd'>
#   <div id="cba0df7a-5c3a-4690-a712-066b9ed468fd" data-root-id="df015450-5a24-4387-90dd-71debce953bd" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e99da21b-f594-44af-8a0f-62d4a7d73005":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"df015450-5a24-4387-90dd-71debce953bd"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"135a6582-1dac-4323-85d6-a72379dcbeed","attributes":{"plot_id":"df015450-5a24-4387-90dd-71debce953bd","comm_id":"0b4ff654abca4bcaaedd1274b03f3b26","client_comm_id":"9c2b0ac0294449e59e27b89b96e4c6ed"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"e99da21b-f594-44af-8a0f-62d4a7d73005","roots":{"df015450-5a24-4387-90dd-71debce953bd":"cba0df7a-5c3a-4690-a712-066b9ed468fd"},"root_ids":["df015450-5a24-4387-90dd-71debce953bd"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.21.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.5.2">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>

# %% [markdown]
# ## Registers

# %%
# Regular sine wave
modulation_amplitude = 0
microstep_amplitude = 248
microstep_sine_offset = 1

MSLUT = [
    0xAAAAB554,
    0x4A9554AA,
    0x24492929,
    0x10104222,
    0xF8000000,
    0xB5BB777D,
    0x49295556,
    0x00404222,
]

MSLUTSEL = 0xFFFF9A56
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Regular sine wave
modulation_amplitude = 0
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0x55555AAA,
    0xA54AAA55,
    0x12249494,
    0x8082111,
    0xFC000000,
    0x5ADDBBBE,
    0x2494AAAB,
    0x202111,
]

MSLUTSEL = 0xFFFF9956
MSLUTSTART = microstep_sine_offset | (247 << 16)

# %%
# Negative modulation TMCL-IDE
modulation_amplitude = -20
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0xFF7EF7BA,
    0x29220FFF,
    0xBBBB6B55,
    0x6DBBDEF7,
    0x08224AAD,
    0xA5ADB7E0,
    0x01084492,
    0x00001001,
]

MSLUTSEL = 0xFFA42B59
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Positive modulation TMCL-IDE
modulation_amplitude = 20
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0x00410888,
    0xA55B6F80,
    0xDFF08084,
    0x56ADADDD,
    0x5AD56AAD,
    0x76EDDB6B,
    0xB6DB7777,
    0x02114AAA,
]

MSLUTSEL = 0xFF53265B
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Max modulation TMCL-IDE
modulation_amplitude = 39
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0x56ddfefe,
    0x4ab80012,
    0x95ade004,
    0x02008224,
    0x22100800,
    0xfbb6d549,
    0xfffffffd,
    0x08956def,
]

MSLUTSEL = 0xdd4c325b
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Min modulation TMCL-IDE
modulation_amplitude = -27
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0xeed6ad54,
    0x52207f7e,
    0xdff7bb55,
    0xdfffffff,
    0x022555bb,
    0x255adc00,
    0x00810449,
    0x20,
]

MSLUTSEL = 0xffa92e59
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Sine Offset
modulation_amplitude = 0
microstep_amplitude = 124
microstep_sine_offset = 124

MSLUT = [
    0xDDDDDEEE,
    0xB76EEEDD,
    0xDB6DB6DB,
    0x55AB5ADA,
    0x954AAAAD,
    0x1249494A,
    0x82108889,
    0x00020080,
]

MSLUTSEL = 0xFFFFFF55
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Custom modulation
modulation_amplitude = 15 # ?
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0xC0410844,
    0x2AAB77DF,
    0xBE000211,
    0xAB56B6DB,
    0xB6D6AD56,
    0xDDDDBB6D,
    0x5AD76DDD,
    0x01049255,
]

MSLUTSEL = (3) | (2 << 2) | (1 << 4) | (1 << 6) | (30 << 8) | (88 << 16) | (220 << 24)
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Max custom modulation
modulation_amplitude = 31 # ?
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0x5BBDFFFF,
    0x4ADE0849,
    0x4955B808,
    0x8,
    0x4A220800,
    0xFEFBB6D5,
    0xEFDFFFF7,
    0x224AB6D,
]

MSLUTSEL = (3) | (2 << 2) | (1 << 4) | (1 << 6) | (48 << 8) | (74 << 16) | (220 << 24)
MSLUTSTART = microstep_sine_offset | (248 << 16)

# %%
# Bad registers
modulation_amplitude = 0 # ?
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0x0,
    0x0,
    0x0,
    0x0,
    0x0,
    0x0,
    0x0,
    0x0,
]

MSLUTSEL = 0x0
MSLUTSTART = 0x0

# %%
# Default table
modulation_amplitude = 0 # ?
microstep_amplitude = 248
microstep_sine_offset = 0

MSLUT = [
    0xaaaab554,
    0x4a9554aa,
    0x24492929,
    0x10104222,
    0xfbffffff,
    0xb5bb777d,
    0x49295556,
    0x00404222,
]

MSLUTSEL = 0xffff8056
MSLUTSTART = 0x00f70000

# %% [markdown]
# ## Plot wave from registers

# %%
lut = LUT.CreateFromRegisters(MSLUT, MSLUTSEL, MSLUTSTART)
wave = lut.GetWaveform()

wave_plot = hv.Curve(wave, kdims='microsteps', vdims='amplitude', label="Wave from registers").opts(
    title=f"Microstep full wave, modulation amplitude = {modulation_amplitude}",
    xlabel="Microstep",
    ylabel="Sin Wave"
)

registers = hv.Table({
    'Register': ["MSLUT[0]", "MSLUT[1]", "MSLUT[2]", "MSLUT[3]", "MSLUT[4]", "MSLUT[5]", "MSLUT[6]", "MSLUT[7]", "MSLUTSEL", "MSLUTSTART"],
    'Value': [hex(mslut) for mslut in lut.mslut] + [hex(lut.mslutsel), hex(lut.mslutstart)]},
    kdims=['Register'], vdims=['Value'])

fft_plot = hv.Bars(lut.GetFFT(wave), kdims='frequency', vdims=['amplitude', 'phase']).opts(
    xlabel="Frequency",
    ylabel="Amplitude",
    xlim=(0, max_freq := 50),
    xticks=min(int(max_freq), 50)
)

plot = hv.Layout(wave_plot + fft_plot + registers).cols(1)

hv.save(plot, f"graphs/{wave_plot.opts.get().kwargs['title']}.html")
plot
# Out:
# :Layout
#    .Curve.Wave_from_registers :Curve   [microsteps]   (amplitude)
#    .Bars.I                    :Bars   [frequency]   (amplitude,phase)
#    .Table.I                   :Table   [Register]   (Value)

# %%
modulation_amplitude = -0.08
LUT.CreateFromFunction(lambda x: np.sin(2*np.pi*x/1024+0*np.pi/1024) + modulation_amplitude *
                       np.sin(3*2*np.pi*x/1024) + modulation_amplitude * np.sin(5*2*np.pi*x/1024))

# %% [markdown]
# ## Plot wave from function

# %%
def CreateCurve(modulation_amplitude3: int = 0, modulation_amplitude5: int = 0, amplitude_scaler: int = 248, offset: int = 0):
    def wave_function(x: int):
        return np.sin(2*np.pi*x/1024+np.pi/1024) + modulation_amplitude3 * np.sin(3*2*np.pi*x/1024) + modulation_amplitude5 * np.sin(5*2*np.pi*x/1024)
    
    expected_wave_plot = hv.Curve([wave_function(i) * amplitude_scaler + offset for i in range(1024)], label="Expected wave")

    try:
        lut = LUT.CreateFromFunction(wave_function, amplitude_scaler=amplitude_scaler, offset=offset)
        wave = lut.GetWaveform()
        wave_plot = plt.CreateWaveformPlot(wave, label="Actual wave")
        fft_plot = plt.CreateFftPlot(lut.GetFFT(wave))
        registers = plt.CreateRegisterTable(lut)
    except Exception as e:
        print(e)
        wave_plot = hv.Curve((0,0))
        fft_plot = hv.Bars((0, 0), kdims='frequency', vdims='amplitude')
        registers = hv.Table({'Register': [], 'Value': []}, 'Register', 'Value')


    return hv.Layout(expected_wave_plot * wave_plot + fft_plot + registers).cols(1)


dmap = hv.DynamicMap(CreateCurve, kdims=['modulation_amplitude3',
                     'modulation_amplitude5', 'amplitude_scaler', 'offset'])
dmap = dmap.redim.range(modulation_amplitude3=(-0.5, 0.5), modulation_amplitude5=(-0.5, 0.5), amplitude_scaler=(0, 248), offset=(-1, 248))
dmap = dmap.redim.step(modulation_amplitude3=0.01, modulation_amplitude5=0.01, amplitude_scaler=1, offset=1)
dmap = dmap.redim.default(modulation_amplitude3=0, modulation_amplitude5=0, amplitude_scaler=248, offset=0)
dmap = dmap.opts(
    opts.Curve(
        title=f"Microstep full wave",
        xlabel="Microstep",
        ylabel="Sin Wave",
        xlim=(0, 1024),
        ylim=(-248, 248)
    ))
dmap
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'c2d69a89-5191-43b8-a8c6-1d3bc7ce209f': {'version…

# %% [markdown]
# # Testing
#
# Send a single microstep move and read MSCNT & MSCURACT to get the actual MSLUT waveform

# %%
from duetwebapi import DuetWebAPI
from WaveTest import GetSineTable

modulation_amplitude = 0
microstep_amplitude = 248
microstep_offset = 0
# title = f"Measured LUT - Modulation amplitude = {modulation_amplitude}"
title = f"Measured LUT - Default"

duet = DuetWebAPI('192.168.4.87')
# duet.send_code(f"M569.9 P0 A{microstep_amplitude} J{modulation_amplitude} C{microstep_offset}")

actualWave = GetSineTable(duet, microsteps=1024)

actualLut = LUT.CreateFromWave([d['coilA'] for d in actualWave], 256)

coilA_plot = hv.Scatter(actualWave, kdims=['position'], vdims=['coilA'], label="coilA")
coilB_plot = hv.Scatter(actualWave, kdims=['position'], vdims=['coilB'], label="coilB")

wave = actualLut.GetWaveform()
actual_wave_plot = plt.CreateWaveformPlot(wave, "Recreated wave")
actual_fft_plot = plt.CreateFftPlot(actualLut.GetFFT(wave))
actual_register_table = plt.CreateRegisterTable(actualLut)

plot = hv.Layout([
    hv.Overlay([coilA_plot, coilB_plot, actual_wave_plot]),
    actual_fft_plot,
    actual_register_table,
]).cols(1).opts(title=title)
hv.save(plot, f"graphs/measured/{title}.html")
plot
# Out:
# 2024-10-04 12:03:27.425 | INFO     | WaveTest:GetSineTable:48 - Microstep: 0/1024
# 2024-10-04 12:03:27.575 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x0
# 2024-10-04 12:03:27.702 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf70000
# 2024-10-04 12:03:27.943 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1/1024
# 2024-10-04 12:03:28.074 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3ff
# 2024-10-04 12:03:28.197 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701ff
# 2024-10-04 12:03:28.456 | INFO     | WaveTest:GetSineTable:48 - Microstep: 2/1024
# 2024-10-04 12:03:28.594 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3fe
# 2024-10-04 12:03:28.748 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701fe
# 2024-10-04 12:03:28.968 | INFO     | WaveTest:GetSineTable:48 - Microstep: 3/1024
# 2024-10-04 12:03:29.111 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3fd
# 2024-10-04 12:03:29.251 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701fc
# 2024-10-04 12:03:29.504 | INFO     | WaveTest:GetSineTable:48 - Microstep: 4/1024
# 2024-10-04 12:03:29.634 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3fc
# 2024-10-04 12:03:29.759 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701fb
# 2024-10-04 12:03:30.009 | INFO     | WaveTest:GetSineTable:48 - Microstep: 5/1024
# 2024-10-04 12:03:30.153 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3fb
# 2024-10-04 12:03:30.276 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701f9
# 2024-10-04 12:03:30.502 | INFO     | WaveTest:GetSineTable:48 - Microstep: 6/1024
# 2024-10-04 12:03:30.645 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3fa
# 2024-10-04 12:03:30.784 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701f8
# 2024-10-04 12:03:31.021 | INFO     | WaveTest:GetSineTable:48 - Microstep: 7/1024
# 2024-10-04 12:03:31.169 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3f9
# 2024-10-04 12:03:31.310 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701f6
# 2024-10-04 12:03:31.560 | INFO     | WaveTest:GetSineTable:48 - Microstep: 8/1024
# 2024-10-04 12:03:31.708 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3f8
# 2024-10-04 12:03:31.843 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701f5
# 2024-10-04 12:03:32.067 | INFO     | WaveTest:GetSineTable:48 - Microstep: 9/1024
# 2024-10-04 12:03:32.195 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3f7
# 2024-10-04 12:03:32.335 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701f3
# 2024-10-04 12:03:32.569 | INFO     | WaveTest:GetSineTable:48 - Microstep: 10/1024
# 2024-10-04 12:03:32.695 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3f6
# 2024-10-04 12:03:32.820 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf701f2
# 2024-10-04 12:03:33.043 | INFO     | WaveTest:GetSineTable:48 - Microstep: 11/1024
# 2024-10-04 12:03:33.189 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3f5
# 2024-10-04 12:03:33.308 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf601f0
# 2024-10-04 12:03:33.530 | INFO     | WaveTest:GetSineTable:48 - Microstep: 12/1024
# 2024-10-04 12:03:33.674 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3f4
# 2024-10-04 12:03:33.809 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf601ef
# 2024-10-04 12:03:34.040 | INFO     | WaveTest:GetSineTable:48 - Microstep: 13/1024
# 2024-10-04 12:03:34.180 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3f3
# 2024-10-04 12:03:34.317 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf
| DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf6001a
# 2024-10-04 12:12:17.567 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1008/1024
# 2024-10-04 12:12:17.731 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x10
# 2024-10-04 12:12:17.903 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf60018
# 2024-10-04 12:12:18.171 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1009/1024
# 2024-10-04 12:12:18.333 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0xf
# 2024-10-04 12:12:18.485 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf60017
# 2024-10-04 12:12:18.735 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1010/1024
# 2024-10-04 12:12:18.865 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0xe
# 2024-10-04 12:12:19.022 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf60015
# 2024-10-04 12:12:19.260 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1011/1024
# 2024-10-04 12:12:19.389 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0xd
# 2024-10-04 12:12:19.552 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf60014
# 2024-10-04 12:12:19.800 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1012/1024
# 2024-10-04 12:12:19.944 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0xc
# 2024-10-04 12:12:20.080 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf60012
# 2024-10-04 12:12:20.305 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1013/1024
# 2024-10-04 12:12:20.450 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0xb
# 2024-10-04 12:12:20.588 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf60010
# 2024-10-04 12:12:20.823 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1014/1024
# 2024-10-04 12:12:21.084 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0xa
# 2024-10-04 12:12:21.219 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf6000f
# 2024-10-04 12:12:21.452 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1015/1024
# 2024-10-04 12:12:21.587 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x9
# 2024-10-04 12:12:21.720 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf7000d
# 2024-10-04 12:12:21.943 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1016/1024
# 2024-10-04 12:12:22.080 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x8
# 2024-10-04 12:12:22.323 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf7000c
# 2024-10-04 12:12:22.560 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1017/1024
# 2024-10-04 12:12:22.689 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x7
# 2024-10-04 12:12:22.827 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf7000a
# 2024-10-04 12:12:23.113 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1018/1024
# 2024-10-04 12:12:23.247 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x6
# 2024-10-04 12:12:23.421 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf70009
# 2024-10-04 12:12:23.650 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1019/1024
# 2024-10-04 12:12:23.781 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x5
# 2024-10-04 12:12:23.922 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf70007
# 2024-10-04 12:12:24.143 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1020/1024
# 2024-10-04 12:12:24.291 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x4
# 2024-10-04 12:12:24.451 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf70006
# 2024-10-04 12:12:24.684 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1021/1024
# 2024-10-04 12:12:24.813 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x3
# 2024-10-04 12:12:24.943 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf70004
# 2024-10-04 12:12:25.188 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1022/1024
# 2024-10-04 12:12:25.340 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x2
# 2024-10-04 12:12:25.504 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf70003
# 2024-10-04 12:12:25.749 | INFO     | WaveTest:GetSineTable:48 - Microstep: 1023/1024
# 2024-10-04 12:12:25.885 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6a] = 0x1
# 2024-10-04 12:12:26.033 | DEBUG    | WaveTest:GetRegister:28 - Register[0x6b] = 0xf70001
# :Layout
#    .Overlay.I :Overlay
#       .Scatter.CoilA        :Scatter   [position]   (coilA)
#       .Scatter.CoilB        :Scatter   [position]   (coilB)
#       .Curve.Recreated_wave :Curve   [x]   (y)
#    .Bars.I    :Bars   [frequency]   (amplitude,phase)
#    .Table.I   :Table   [Register]   (Value)

# %%
defaultWave = actualWave

# %%
(hv.Scatter((defaultWave['position'], defaultWave['coilA']), label="coilA") * hv.Scatter((defaultWave['position'], defaultWave['coilB']), label="coilB")).opts(title="Default MSLUT")
# Out:
# :Overlay
#    .Scatter.CoilA :Scatter   [x]   (y)
#    .Scatter.CoilB :Scatter   [x]   (y)

# %% [markdown]
# ## Prusa Phase Stepping
#
# Prusa add up to 16 harmonics to the stepper motor sine wave on the XL.

# %%
MOTOR_PERIOD = 1024
SIN_FRACTION = 4
SIN_PERIOD = SIN_FRACTION * MOTOR_PERIOD
CURRENT_AMPLITUDE = 248

sin_lut_values = [min(256, max(0, int(CURRENT_AMPLITUDE * np.sin(np.pi / 2.0 * i / (SIN_PERIOD / 4)) + 0.5)))
                  for i in range(1 + int(SIN_PERIOD / 4))]
phase_shift = [0] * MOTOR_PERIOD


class SpectralItem:
    def __init__(self, mag: float, pha: float):
        self.mag: float = mag
        self.pha: float = pha


spectrum = [
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0.02679, 2.54170),
    SpectralItem(0, 0),
    SpectralItem(0.01984, -0.69422),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
    SpectralItem(0, 0),
]


def normalise_sin_phase(phase: int):
    phase = phase % SIN_PERIOD
    if phase < 0:
        phase += SIN_PERIOD
    return phase


def normalise_motor_phase(phase: int):
    phase = phase % MOTOR_PERIOD
    if phase < 0:
        phase += MOTOR_PERIOD
    return phase


def sin_lut(x: int):
    x = normalise_sin_phase(x)
    if (x <= SIN_PERIOD / 4):
        return sin_lut_values[x]
    if (x <= SIN_PERIOD / 2):
        return sin_lut_values[int(SIN_PERIOD / 2) - x]
    if (x <= 3 * SIN_PERIOD / 4):
        return -sin_lut_values[x - int(SIN_PERIOD / 2)]
    return -sin_lut_values[SIN_PERIOD - x]


def cos_lut(x: int):
    return sin_lut(x + int(SIN_PERIOD / 4))


def update_phase_shift():
    for i in range(len(phase_shift)):
        item_phase: float = i * 2 * np.pi / MOTOR_PERIOD
        shift: float = 0
        for n, s in enumerate(spectrum):
            shift += s.mag * np.sin(n * item_phase + s.pha)
        phase_shift[i] = round(SIN_PERIOD / (2 * np.pi) * shift)


def get_current(idx: int):
    pha: int = int(SIN_FRACTION * idx + phase_shift[normalise_motor_phase(idx)])
    return (sin_lut(pha), cos_lut(pha))


# def alternative_get_current(idx: int):
#     item_phase = idx * 2 * np.pi / MOTOR_PERIOD

#     coilA = CURRENT_AMPLITUDE * (np.sin(item_phase + * (np.sin(3 * item_phase +
#                                                                           phase3)) + (harmonic5 * np.sin(5 * item_phase + phase5)))
#     coilB = CURRENT_AMPLITUDE * (np.cos(item_phase) - harmonic3 * (np.cos(3 * item_phase +
#                                                                           phase3)) + (harmonic5 * np.cos(5 * item_phase + phase5)))
#     return (coilA, coilB)

def create_prusa_plot(mag2: float, mag4: float, pha2: float, pha4: float):
    spectrum[2] = SpectralItem(mag2, pha2)
    spectrum[4] = SpectralItem(mag4, pha4)

    update_phase_shift()

    data = {
        'pha': list(range(MOTOR_PERIOD)),
        'sin': [sin_lut(i * SIN_FRACTION) for i in range(MOTOR_PERIOD)],
        'cos': [cos_lut(i * SIN_FRACTION) for i in range(MOTOR_PERIOD)],
        'phase_shift': phase_shift,
        'coilA': [get_current(i)[0] for i in range(MOTOR_PERIOD)],
        'coilB': [get_current(i)[1] for i in range(MOTOR_PERIOD)],
    }
    sin_plot = hv.Curve(data, kdims='pha', vdims=['sin'], label="sin").opts(muted=True)
    cos_plot = hv.Curve(data, kdims='pha', vdims=['cos'], label="cos").opts(muted=True)
    coilA_plot = hv.Curve(data, kdims='pha', vdims=['coilA', 'sin', 'phase_shift'], label="coilA")
    coilB_plot = hv.Curve(data, kdims='pha', vdims=['coilB', 'cos', 'phase_shift'], label="coilB")
    phase_shift_plot = hv.Curve(data, kdims='pha', vdims=['phase_shift'], label="Phase shift")
    fft_plot = hv.Layout([
        hv.Bars(CalculateFFT(data['coilA']), kdims='frequency', vdims=['amplitude', 'phase'], label="coilA FFT"),
        hv.Bars(CalculateFFT(data['coilB']), kdims='frequency', vdims=['amplitude', 'phase'], label="coilB FFT"),
        ]).cols(2).opts(
        opts.Bars(
            xlabel="Harmonic",
            ylabel="Amplitude",
            xlim=(0, max_freq := 50),
            xticks=min(int(max_freq), 50),
            color='phase',
            colorbar=True,
            clabel="Phase"
    ))
    plot = hv.Layout([
        (sin_plot * cos_plot * coilA_plot * coilB_plot).opts(ylabel="Amplitude"),
        (phase_shift_plot).opts(ylabel="Phase Shift"),
        fft_plot,
    ]).cols(2)
    return plot

update_phase_shift()
dmap = hv.DynamicMap(create_prusa_plot, kdims=['mag2', 'mag4', 'pha2', 'pha4'])
dmap = dmap.redim.range(mag2=(0.01 - 0.035-0, 0.01 + 0.035+0), mag4=(0.015 - 0.03-0, 0.015 + 0.03+0), pha2=(np.pi-2.5, np.pi+2.5), pha4=(-2.75, 2.75))
dmap = dmap.redim.step(mag2=0.005, mag4=0.005, pha2=0.005, pha4=0.005)
dmap = dmap.redim.default(mag2=spectrum[2].mag, mag4=spectrum[4].mag, pha2=spectrum[2].pha, pha4=spectrum[4].pha)
# hv.save(plot, "graphs/Prusa Waveform.html")
dmap
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'39ea4daf-3f3a-4d4c-a234-6b46aa112008': {'version…

# %%
def dft_n_mag(signal: list[float], n: int):
    sum_sin: float = 0
    sum_cos: float = 0
    for i, s in enumerate(signal):
        x: float = 2 * np.pi * i * n / len(signal)
        y: float = s
        sum_sin += y * np.sin(x)
        sum_cos += y * np.cos(x)
    return np.sqrt(sum_sin * sum_sin + sum_cos * sum_cos)



def CreatePrusaDftPlot(harmonic: int, motor_period_count: int):
    signal = [np.sin(x * 2*np.pi/1024) + 0.5*np.sin(3*x * 2*np.pi/1024) for x in range(motor_period_count * 1024)]
    harm: int = harmonic * motor_period_count
    a1: float = dft_n_mag(signal, harm - 1)
    a2: float = dft_n_mag(signal, harm)
    a3: float = dft_n_mag(signal, harm + 1)
    res: float = (a1 + a2 + a3) / 3
    return hv.Overlay([
        hv.Bars((harm - 1, a1), label="a1"),
        hv.Bars((harm, a2), label="a2"),
        hv.Bars((harm + 1, a3), label="a3"),
        hv.Bars((harmonic, res), label="res"),
    ]).opts(xlim=(0, motor_period_count), ylim=(0, 1000))


dmap = hv.DynamicMap(CreatePrusaDftPlot, kdims=['harmonic', 'motor_period_count'])
dmap = dmap.redim.range(harmonic=(0, 10), motor_period_count=(3, 50))
dmap = dmap.redim.step(harmonic=1, motor_period_count=1)
dmap = dmap.redim.default(harmonic=2, motor_period_count=50)
dmap
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'e46fe665-7b6f-4ab5-9304-e96902400154': {'version…
